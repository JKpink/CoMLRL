# %% [markdown]
# # Multi-Agent Collaborative Writing with QLoRA
# ## CoMLRL IAC Trainer + Qwen3-0.6B 4-bit on Kaggle T4×2
#
# - Agent A: Concise summarizer (~220 chars)
# - Agent B: Detailed writer (2-3x longer)
# - Method: IAC (Independent Actor-Critic) + QLoRA 4-bit

# %%
# !pip install -q transformers datasets peft bitsandbytes accelerate torch tqdm pyyaml

# %%
import os
REPO = "https://github.com/YOUR_USER/CoMLRL.git"  # TODO: update this
DIR = "CoMLRL"

if not os.path.exists(DIR):
    # !git clone {REPO}
else:
    # %cd {DIR}
    # !git pull origin main
    # %cd ..

import sys

# %cd {DIR}
# !pip install -e . --quiet
# %cd ..

sys.path.insert(0, DIR)

import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA: {torch.cuda.is_available()}, GPUs: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    print(f"  GPU {i}: {torch.cuda.get_device_name(i)} ({torch.cuda.get_device_properties(i).total_memory / 1024**3:.1f} GB)")

# %%
# %cd CoMLRL
# !python examples/tldr_simple.py \
    --model-name Qwen/Qwen3-0.6B \
    --dataset-size 320 \
    --num-train-epochs 3 \
    --agent-devices cuda:0 cuda:1 \
    --output-dir ./outputs/iac_simple
# %cd ..

# %%
# !mkdir -p /kaggle/working/outputs
# !cp -r CoMLRL/outputs/iac_simple /kaggle/working/outputs/
print("Models saved!")
