# %% [markdown]
# # Multi-Agent Collaborative Code Generation — Training
# ## IAC + Qwen3-0.6B bf16 on Kaggle T4×2
#
# - Agent A: Helper function writer
# - Agent B: Main function + test writer
# - Dataset: HumanEval

# %%
# !pip install -q transformers datasets accelerate tqdm pyyaml

# %%
import os, torch
print(f"CUDA: {torch.cuda.is_available()}, GPUs: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    print(f"  GPU {i}: {torch.cuda.get_device_name(i)} ({torch.cuda.get_device_properties(i).total_memory / 1024**3:.1f} GB)")

# %%
import os
REPO = "https://github.com/JKpink/CoMLRL.git"
DIR = "CoMLRL"

if not os.path.exists(DIR):
    # !git clone {REPO}
else:
    # %cd {DIR}
    # !git pull origin main
    # %cd ..

# %cd {DIR}
# !pip install -q -e . --no-deps

# %%
# !python examples/code_collab.py \
    --model-name Qwen/Qwen3-0.6B \
    --dataset-size 100 \
    --num-train-epochs 15 \
    --output-dir ./outputs/magrpo_code

# %%
# !mkdir -p /kaggle/working/outputs
# !cp -r outputs/iac_code /kaggle/working/outputs/
print("Weights saved to /kaggle/working/outputs/iac_code")
